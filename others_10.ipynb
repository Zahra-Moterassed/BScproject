# %%
#DIF 2023
import numpy as np
import pandas as pd
from pyod.models.iforest import IForest
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_dif_outlier_scores(data):
    """
    Calculate outlier scores using the DIF model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply DIF from pyod
    dif = IForest()
    dif.fit(data)

    # Get the outlier scores
    outlier_scores = dif.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_dif_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate ECOD outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
# DIF
# dataset: Annthyroid_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Annthyroid\\Annthyroid_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.678324726525626

# %%
# DIF
# dataset: Arrhythmia_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Arrhythmia\\Arrhythmia_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.7795918367346939

# %%
# DIF
# dataset: Cardiotocography_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Cardiotocography\\Cardiotocography_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8431224899598394

# %%
# DIF
# dataset: Hepatitis_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Hepatitis\\Hepatitis_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8538461538461537

# %%
# DIF
# dataset: Lymphography_withoutdupl_norm_1ofn.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Lymphography\\Lymphography_withoutdupl_norm_1ofn.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-2].values

# Separate labels (last column)
labels = df.iloc[:, -2].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 1.0

# %%
# DIF
# dataset: Parkinson_withoutdupl_norm_10_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Parkinson\\Parkinson_withoutdupl_norm_10_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8700000000000001

# %%
# DIF
# dataset: Pima_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Pima\\Pima_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.6765000000000001

# %%
#SUOD 2021
import numpy as np
import pandas as pd
from pyod.models.suod import SUOD
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_suod_outlier_scores(data):
    """
    Calculate outlier scores using the SUOD model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply SUOD from pyod
    suod = SUOD()
    suod.fit(data)

    # Get the outlier scores
    outlier_scores = suod.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_suod_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
# SUOD
# dataset: Annthyroid_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Annthyroid\\Annthyroid_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.6598756177466822

# %%
# SUOD
# dataset: Arrhythmia_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Arrhythmia\\Arrhythmia_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.8612244897959183

# %%
# SUOD
# dataset: Cardiotocography_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Cardiotocography\\Cardiotocography_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.879066265060241

# %%
# SUOD
# dataset: Hepatitis_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Hepatitis\\Hepatitis_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.7461538461538462

# %%
# SUOD
# dataset: Lymphography_withoutdupl_norm_1ofn.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Lymphography\\Lymphography_withoutdupl_norm_1ofn.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-2].values

# Separate labels (last column)
labels = df.iloc[:, -2].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.9896551724137932

# %%
# SUOD
# dataset: Parkinson_withoutdupl_norm_10_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Parkinson\\Parkinson_withoutdupl_norm_10_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.9800000000000001

# %%
# SUOD
# dataset: Pima_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Pima\\Pima_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.7980000000000002

# %%
#LUNAR 2022
import numpy as np
import pandas as pd
from pyod.models.lunar import LUNAR
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_lunar_outlier_scores(data):
    """
    Calculate outlier scores using the lunar model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply LUNAR from pyod
    lunar = LUNAR()
    lunar.fit(data)

    # Get the outlier scores
    outlier_scores = lunar.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_lunar_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
# LUNAR
# dataset: Annthyroid_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Annthyroid\\Annthyroid_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.5769865067466267

# %%
# LUNAR
# dataset: Arrhythmia_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Arrhythmia\\Arrhythmia_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.7877551020408163

# %%
# LUNAR
# dataset: Cardiotocography_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Cardiotocography\\Cardiotocography_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.7620983935742973

# %%
# LUNAR
# dataset: Hepatitis_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Hepatitis\\Hepatitis_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.7

# %%
# LUNAR
# dataset: Lymphography_withoutdupl_norm_1ofn.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Lymphography\\Lymphography_withoutdupl_norm_1ofn.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-2].values

# Separate labels (last column)
labels = df.iloc[:, -2].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.9275862068965518

# %%
# LUNAR
# dataset: Parkinson_withoutdupl_norm_10_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Parkinson\\Parkinson_withoutdupl_norm_10_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8400000000000001

# %%
# LUNAR
# dataset: Pima_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Pima\\Pima_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.7215

# %%
#ROD 2020
import numpy as np
import pandas as pd
from pyod.models.rod import ROD
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_rod_outlier_scores(data):
    """
    Calculate outlier scores using the ROD model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply ROD from pyod
    rod = ROD()
    rod.fit(data)

    # Get the outlier scores
    outlier_scores = rod.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_rod_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate ECOD outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
# ROD
# dataset: Cardiotocography_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Cardiotocography\\Cardiotocography_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8605421686746988

# %%
# ROD
# dataset: Hepatitis_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Hepatitis\\Hepatitis_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.9153846153846154

# %%
# ROD
# dataset: Lymphography_withoutdupl_norm_1ofn.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Lymphography\\Lymphography_withoutdupl_norm_1ofn.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-2].values

# Separate labels (last column)
labels = df.iloc[:, -2].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.9689655172413791

# %%
# ROD
# dataset: Parkinson_withoutdupl_norm_10_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Parkinson\\Parkinson_withoutdupl_norm_10_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.9200000000000002

# %%
# ROD
# dataset: Pima_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Pima\\Pima_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.5585

# %%
# ROD
# dataset: Arrhythmia_withoutdupl_norm_02_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\Arrhythmia\\Arrhythmia_withoutdupl_norm_02_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 1
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[25], line 30
#      27 X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)
#      29 # Calculate outlier scores on the training set
# ---> 30 predicted_outlier_scores = calculate_rod_outlier_scores(X_train)
#      32 # Evaluate the performance on the validation set
#      33 val_outlier_scores = calculate_rod_outlier_scores(X_val)
#
# Cell In[8], line 19, in calculate_rod_outlier_scores(data)
#      17 # Apply ROD from pyod
#      18 rod = ROD()
# ---> 19 rod.fit(data)
#      21 # Get the outlier scores
#      22 outlier_scores = rod.decision_scores_  # higher score -> more outlier
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python39\lib\site-packages\pyod\models\rod.py:407, in ROD.fit(self, X, y)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=404'>405</a> self.angles_scaler1_ = None  # scaler(s) of Angles Group 1
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=405'>406</a> self.angles_scaler2_ = None  # scaler(s) of Angles Group 2
# --> <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=406'>407</a> self.decision_scores_ = self.decision_function(X)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=407'>408</a> self._process_decision_scores()
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=409'>410</a> return self
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python39\lib\site-packages\pyod\models\rod.py:443, in ROD.decision_function(self, X)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=434'>435</a>     scores, self.gm_, self.median_, self.angles_scaler1_, \
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=435'>436</a>         self.angles_scaler2_ = rod_3D(x=X, gm=self.gm_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=436'>437</a>                                       median=self.median_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=437'>438</a>                                       scaler1=self.angles_scaler1_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=438'>439</a>                                       scaler2=self.angles_scaler2_)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=439'>440</a>     return scores
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=441'>442</a> scores, self.gm_, self.median_, self.data_scaler_, \
# --> <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=442'>443</a>     self.angles_scaler1_, self.angles_scaler2_ = rod_nD(X=X,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=443'>444</a>                                                         parallel=self.parallel_execution,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=444'>445</a>                                                         gm=self.gm_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=445'>446</a>                                                         median=self.median_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=446'>447</a>                                                         data_scaler=self.data_scaler_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=447'>448</a>                                                         angles_scalers1=self.angles_scaler1_,
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=448'>449</a>                                                         angles_scalers2=self.angles_scaler2_)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=449'>450</a> return scores
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python39\lib\site-packages\pyod\models\rod.py:325, in rod_nD(X, parallel, gm, median, data_scaler, angles_scalers1, angles_scalers2)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=322'>323</a>     angles_scalers1.append(ang_s1_)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=323'>324</a>     angles_scalers2.append(ang_s2_)
# --> <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=324'>325</a> scores = np.average(np.array(subspaces_scores).T, axis=1).reshape(-1)
#     <a href='file:///c%3A/Users/asus/AppData/Local/Programs/Python/Python39/lib/site-packages/pyod/models/rod.py?line=325'>326</a> return scores, gm, median, data_scaler, angles_scalers1, angles_scalers2
#
# MemoryError: Unable to allocate 4.25 GiB for an array with shape (2895620, 197) and data type float64

# %%
# heart disease 5%

# %%
#ECOD 2022
import numpy as np
import pandas as pd
from pyod.models.ecod import ECOD
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_ecod_outlier_scores(data):
    """
    Calculate outlier scores using the ECOD model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply ECOD from pyod
    ecod = ECOD()
    ecod.fit(data)

    # Get the outlier scores
    outlier_scores = ecod.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_ecod_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate ECOD outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
#COPOD 2020
import numpy as np
import pandas as pd
from pyod.models.copod import COPOD
from sklearn.metrics import precision_score, recall_score, roc_auc_score

def calculate_copod_outlier_scores(data):
    """
    Calculate outlier scores using the COPOD model.

    Args:
        data: Input dataset (numpy array or pandas DataFrame).

    Returns:
        outlier_scores: Array of outlier scores.
    """
    # Apply COPOD from pyod
    copod = COPOD()
    copod.fit(data)

    # Get the outlier scores
    outlier_scores = copod.decision_scores_  # higher score -> more outlier

    return outlier_scores

def evaluate_copod_outlier_detection(outlier_scores, ground_truth):
    """
    Evaluate ECOD outlier detection results using precision, recall, and AUC.

    Args:
        outlier_scores: Array of outlier scores.
        ground_truth: Ground truth labels (numpy array or pandas Series).

    Returns:
        precision: Precision of the model.
        recall: Recall of the model.
        auc: AUC of the model.
    """
    # Calculate precision, recall, and AUC
    threshold = np.percentile(outlier_scores, 90)  # Setting threshold at the 90th percentile for demonstration
    predictions = (outlier_scores >= threshold).astype(int)  # Classify as 1 if above threshold (outlier), else 0

    precision = precision_score(ground_truth, predictions)
    recall = recall_score(ground_truth, predictions)
    auc = roc_auc_score(ground_truth, outlier_scores)

    return precision, recall, auc

# %%
# ECOD
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_ecod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_ecod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_ecod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.835483870967742

# %%
# COPOD
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_copod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_copod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_copod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8870967741935484

# %%
# ROD
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_rod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_rod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_rod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8548387096774194

# %%
# DIF
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_dif_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_dif_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_dif_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.9129032258064516

# %%
# SUOD
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_suod_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_suod_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_suod_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# RandomForestRegressor()
#
# Average AUC over 10 runs: 0.8967741935483872

# %%
# LUNAR
# dataset: HeartDisease_withoutdupl_norm_05_v01.csv
# 10 times
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# File path to the dataset
file_path = "G:\\Nazanin\\B project\\code\\dataset\\HeartDisease\\HeartDisease_withoutdupl_norm_05_v01.csv"

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Separate data (all columns except the last)
data = df.iloc[:, :-1].values

# Separate labels (last column)
labels = df.iloc[:, -1].values

# Number of iterations
num_runs = 10
auc_scores = []

for _ in range(num_runs):
    # Split the data into training and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, stratify=labels, random_state=None)

    # Calculate outlier scores on the training set
    predicted_outlier_scores = calculate_lunar_outlier_scores(X_train)

    # Evaluate the performance on the validation set
    val_outlier_scores = calculate_lunar_outlier_scores(X_val)

    # Evaluate the performance
    precision, recall, auc = evaluate_lunar_outlier_detection(val_outlier_scores, y_val)
    auc_scores.append(auc)

# Calculate the average AUC
average_auc = np.mean(auc_scores)

print("Average AUC over 10 runs:", average_auc)
# Out:
# Average AUC over 10 runs: 0.8612903225806452
